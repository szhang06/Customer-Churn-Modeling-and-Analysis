# %% [markdown]
# # Exploratory Data Analysis Starter
#
# ## Import packages

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [markdown]
# ---
#
# ## Loading data with Pandas

# %%
client_df = pd.read_csv('./client_data.csv')
price_df = pd.read_csv('./price_data.csv')

# %% [markdown]
# View the first 3 rows of a dataframe.

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %% [markdown]
# ---
#
# ## Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Statistics

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# ---
#
# ## Data visualization

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:

        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad), # coordinates of annotation
            color=colour,
            size=textsize
        )

# %% [markdown]
# # Churn

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %% [markdown]
# #### The churn percentage is 9.7% ( it seems all right).

# %% [markdown]
# # Sales Channel

# %%
# churn ratio by channel

channel = client_df[['id', 'channel_sales', 'churn']]
channel = channel.groupby([channel['channel_sales'], channel['churn']])['id'].count().unstack(level=1).fillna(0)
channel_churn = (channel.div(channel.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(channel_churn, 'Sales channel', rot_=30)
plot_stacked_bars(channel.sort_values(by=[1], ascending=False), 'Sales channel', rot_=30)

# %% [markdown]
# # Consumption

# %% [markdown]
# The second function `annotate_bars` is used by the first function, but the third function `plot_distribution` helps you to plot the distribution of a numeric column. An example of how it can be used is given below:

# %%
def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    # select the rows with churn == 0 and then select the [column] column
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=4, figsize=(18, 25))

plot_distribution(consumption, 'cons_12m', axs[0])
plot_distribution(consumption[consumption['has_gas'] == 't'], 'cons_gas_12m', axs[1])
plot_distribution(consumption, 'cons_last_month', axs[2])
plot_distribution(consumption, 'imp_cons', axs[3])

# %% [markdown]
# ##### The visualizations of consumption data (past 12 months, last month, past 12 months gas, and current paid) all exhibit right-skewed distributions with long tails, suggesting the presence of outliers. Further analysis of these outliers is warranted.

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18,25))

# Plot boxplots
sns.boxplot(consumption["cons_12m"], ax=axs[0], orient='h')
sns.boxplot(consumption[consumption["has_gas"] == "t"]["cons_gas_12m"], ax=axs[1], orient='h')
sns.boxplot(consumption["cons_last_month"], ax=axs[2], orient='h')
sns.boxplot(consumption["imp_cons"], ax=axs[3], orient='h')

# Remove scientific notation
for ax in axs:
    ax.ticklabel_format(style='plain', axis='x')
    # Set x-axis limit
    axs[0].set_xlim(-200000, 2000000)
    axs[1].set_xlim(-200000, 2000000)
    axs[2].set_xlim(-20000, 100000)
    plt.show()

# %% [markdown]
# #####Examining churn across sales channels, we observe that it occurs in 5 out of the 8 available channels. A noteworthy finding is that the 'missing' channel exhibits the second highest number of churned customers. This suggests a potential data quality issue or a hidden customer segment not captured by our current channel classifications.
#
# During feature engineering, we should prioritize investigating this 'missing' channel to:
#
# - Identify the root cause: Determine if the missing data is due to errors in data collection, system limitations, or a genuine category of customers with unique characteristics.
# - Impute or create features: Depending on the cause, we might impute missing channel values based on other customer attributes or create a new feature to represent this distinct segment.
# - Tailor retention strategies: Understanding the 'missing' channel could reveal specific pain points or unmet needs, enabling us to develop targeted retention campaigns.

# %% [markdown]
# ##### It seems the relationship between customer antiqueness and churn is a simple decreasing trend.
#
# 1. Visualization:
#
# - Highlight Key Points: On the line chart, consider marking the years with exceptionally high or low churn rates (e.g., year 2, 3, 4, and 12) to draw attention to these anomalies.
#
# 2. Deeper Segmentation:
#
# - Customer Cohorts: Instead of just looking at years, try segmenting customers into cohorts based on their acquisition year. This can reveal if certain cohorts exhibit consistently higher or lower churn rates throughout their lifetime.
# - Additional Factors: Explore other customer attributes that might explain the fluctuations in churn rate. For example, did the company introduce new pricing plans or product features in certain years that could have impacted churn?
#
# 3. Hypothesis Testing:
#
# - External Factors: Investigate whether external factors (e.g., economic conditions, competitor activity) could have influenced churn rates in specific years.
# - Customer Behavior: Analyze the behavior of customers who churned in high-churn years. Are there any patterns in their usage, engagement, or support interactions that could provide clues?
#
# 4. Refine Retention Strategies:
#
# - Targeted Interventions: Based on your analysis, develop targeted retention strategies for different customer segments and time periods.
# - Proactive Measures: Consider proactive measures to address potential churn triggers. For example, if you identify a pattern of increased churn after a price increase, you could offer discounts or loyalty rewards to at-risk customers.

# %% [markdown]
# # Forcast Consumption

# %%
# forcasted consumption for next 12 month
forcast = client_df[['id', 'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
       'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
       'forecast_price_energy_peak', 'forecast_price_pow_off_peak','churn']]

fig, axs = plt.subplots(nrows=7, figsize=(18, 50))

plot_distribution(forcast, 'forecast_cons_12m', axs[0])
plot_distribution(forcast, 'forecast_cons_year', axs[1])
plot_distribution(forcast, 'forecast_discount_energy', axs[2])
plot_distribution(forcast, 'forecast_meter_rent_12m', axs[3])
plot_distribution(forcast, 'forecast_price_energy_off_peak', axs[4])
plot_distribution(forcast, 'forecast_price_energy_peak', axs[5])
plot_distribution(forcast, 'forecast_price_pow_off_peak', axs[6])

# %% [markdown]
# ##### Analysis of the forecasted consumption data reveals a distribution pattern similar to the actual consumption data, characterized by a strong positive skew and long tails. This indicates the presence of outliers or extreme values that can disproportionately influence statistical models.
#
# To ensure the robustness and accuracy of our predictive modeling, we should consider applying transformations to these variables. Common techniques include:
#
# - Logarithmic Transformation
# - Square Root or Cube Root Transformation
# - Box-Cox Transformation

# %%
fig, axs = plt.subplots(nrows=7, figsize=(18,25))

# # Plot boxplots

sns.boxplot(forcast['forecast_cons_12m'],ax=axs[0], orient='h')
sns.boxplot(forcast['forecast_cons_year'],ax=axs[1], orient='h')
sns.boxplot(forcast['forecast_discount_energy'],ax=axs[2], orient='h')
sns.boxplot(forcast['forecast_meter_rent_12m'],ax=axs[3], orient='h')
sns.boxplot(forcast['forecast_price_energy_off_peak'],ax=axs[4], orient='h')
sns.boxplot(forcast['forecast_price_energy_peak'],ax=axs[5], orient='h')
sns.boxplot(forcast['forecast_price_pow_off_peak'],ax=axs[6], orient='h')


# Remove scientific notation
for ax in axs:
    ax.ticklabel_format(style='plain', axis='x')
    plt.show()

# %% [markdown]
# # margin

# %%
# gross margin on power subscription
# gross margin = Total Revenue – COGS

margin = client_df[['id', 'margin_gross_pow_ele', 'margin_net_pow_ele',
       'net_margin','churn']]

fig, axs = plt.subplots(nrows=3, figsize=(18, 20))

plot_distribution(margin, 'margin_gross_pow_ele', axs[0])
plot_distribution(margin, 'margin_net_pow_ele', axs[1])
plot_distribution(margin, 'net_margin', axs[2])

# %%
fig, axs = plt.subplots(nrows=3, figsize=(18,20))
# Plot histogram
sns.boxplot(margin["margin_gross_pow_ele"], ax=axs[0], orient='h')
sns.boxplot(margin["margin_net_pow_ele"],ax=axs[1], orient='h')
sns.boxplot(margin["net_margin"], ax=axs[2], orient='h')
# Remove scientific notation
axs[0].ticklabel_format(style='plain', axis='x')
axs[1].ticklabel_format(style='plain', axis='x')
axs[2].ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# ##### We observe that the margin features also have outliers.

# %% [markdown]
# # Miscellaneous

# %% [markdown]
# # Customer Antiqueness

# %%
# visualize churn ratio by antique years

years_antig = client_df[['id', 'num_years_antig', 'churn']]
years_antig = years_antig.groupby([years_antig['num_years_antig'], years_antig['churn']])['id'].count().unstack(level=1).fillna(0)
years_antig_churn = (years_antig.div(years_antig.sum(axis=1), axis=0) * 100)

plot_stacked_bars(years_antig_churn, 'Years Antig', rot_=0)
plot_stacked_bars(years_antig, 'Years Antig', rot_=0)

# %%
years_antig = client_df[['id', 'num_years_antig', 'churn']]
years_antig = years_antig.groupby([years_antig['num_years_antig'], years_antig['churn']])['id'].count().unstack(level=1).fillna(0)
print(years_antig)
# Out:
# churn                 0      1
# num_years_antig
# 1                   1.0    0.0
# 2                   8.0    3.0
# 3                2104.0  329.0
# 4                3510.0  472.0
# 5                2117.0  200.0
# 6                4430.0  339.0
# 7                 467.0   42.0
# 8                  98.0    5.0
# 9                  91.0    1.0
# 10                 77.0    4.0
# 11                173.0   12.0
# 12                 99.0   11.0
# 13                 12.0    1.0

# %%
# has gas percentage

has_gas = client_df[['id', 'has_gas', 'churn']]
gas = has_gas.groupby([has_gas['has_gas'], has_gas['churn']])['id'].count().unstack(level=1).fillna(0)
gas_churn = (gas.div(gas.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(gas_churn, 'has_gas', rot_=30)

# %% [markdown]
# ##### Has Gas Or Not?

# %%
# has gas absolute number

has_gas = client_df[['id', 'has_gas', 'churn']]
gas = has_gas.groupby([has_gas['has_gas'], has_gas['churn']])['id'].count().unstack(level=1).fillna(0)
# gas_churn = (gas.div(gas.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(gas, 'has_gas', rot_=30)

# %% [markdown]
# ##### Number of Active Products and Services

# %%
# number of active products and services

active_products = client_df[['id', 'nb_prod_act', 'churn']]
products = active_products.groupby([active_products['nb_prod_act'], active_products['churn']])['id'].count().unstack(level=1).fillna(0)
product_percentage = (products.div(products.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(product_percentage, 'nb_prod_act', rot_=30)

# %%
# number of active products and services

active_products = client_df[['id', 'nb_prod_act', 'churn']]
products = active_products.groupby([active_products['nb_prod_act'], active_products['churn']])['id'].count().unstack(level=1).fillna(0)
# gas_churn = (gas.div(gas.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(products, 'nb_prod_act', rot_=30)

# %% [markdown]
# ##### Contract Originality

# %%
# original contract

electricity_campaign = client_df[['id', 'origin_up', 'churn']]
campaign = electricity_campaign.groupby([electricity_campaign['origin_up'], electricity_campaign['churn']])['id'].count().unstack(level=1).fillna(0)
campaign_churn = (campaign.div(campaign.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

plot_stacked_bars(campaign_churn, 'origin_up', rot_=30)

# %% [markdown]
# ###### Subscribed Power

# %%
# subscribed power
power_subscription = client_df[['id', 'pow_max', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(power_subscription, 'pow_max', axs)
